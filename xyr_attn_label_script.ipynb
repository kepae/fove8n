# %%
# !pip install --quiet icecream

# %%
import os
import sys

from icecream import ic
import glob
import matplotlib.pyplot as plt

import numpy as np
from scipy import ndimage
from skimage import color

# %%
if not os.path.isdir('/content/RAFT'):
  # !git clone https://github.com/princeton-vl/RAFT.git
 
sys.path.insert(1,'/content/RAFT/core/')

from utils.frame_utils import readFlow as read_flow
from utils import flow_viz

# %%
if not os.path.isfile('/content/3vids_no_tensors.zip'):
    # !wget https://www.dropbox.com/s/k2esmefb7sg8gxt/3vids_no_tensors.zip
    # !unzip '/content/3vids_no_tensors.zip'
# Out:
# --2021-05-06 02:42:27--  https://www.dropbox.com/s/k2esmefb7sg8gxt/3vids_no_tensors.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/k2esmefb7sg8gxt/3vids_no_tensors.zip [following]
# --2021-05-06 02:42:28--  https://www.dropbox.com/s/raw/k2esmefb7sg8gxt/3vids_no_tensors.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc33452e3f43235022ddaba229d.dl.dropboxusercontent.com/cd/0/inline/BN9fIw2d-lbckeydJMGo_fzopO9kZ1sk_GCW0DQxdFiJt8Zof4kNFrfRgaG15kyjTUUhON_u646N1fp2cMgcBVZdJ8G92099M3Ge35pikVUKQwRAy7gWJqoxUp_iDOy9bujogZJ5kfbKj_GHbn1ukYb8/file# [following]
# --2021-05-06 02:42:28--  https://ucc33452e3f43235022ddaba229d.dl.dropboxusercontent.com/cd/0/inline/BN9fIw2d-lbckeydJMGo_fzopO9kZ1sk_GCW0DQxdFiJt8Zof4kNFrfRgaG15kyjTUUhON_u646N1fp2cMgcBVZdJ8G92099M3Ge35pikVUKQwRAy7gWJqoxUp_iDOy9bujogZJ5kfbKj_GHbn1ukYb8/file
# Resolving ucc33452e3f43235022ddaba229d.dl.dropboxusercontent.com (ucc33452e3f43235022ddaba229d.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:601c:15::a27d:60f
# Connecting to ucc33452e3f43235022ddaba229d.dl.dropboxusercontent.com (ucc33452e3f43235022ddaba229d.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BN9DRN2xz2UEFkyRlsE3P8HirOIVNRsXrLZUe8J-sofoAHixFozfl2mVHqiSj_5-zqyBl1Us9fYEXwYejBlTosUaD7pLCGT_OC0q9o9wF-bwAKpv5Zw18JzjqVnkCD4U9DJ83ke1nFZBrpLHhRouRLec52Ul0yTtZGHO1Bmj_2gDz8fwcgRK3qPm_rT6g_h9960QKsTpCDfugI4R1j3RdBOIwTs0kif1obTtjWH2pCoIp33ZV45c70oL_GX5EOXnReokrAp1VOajrHzyzqh4wOowgN0wUQ8AIZVYQMp64dzZnWwt4GLbXYOTjRf6ju3-LhZjajSrm4Yp7_v0KTC_9pXG_Dw7nySEJBWBKeKyDB5y9PvEZ8-7ZitrPqtzuaDGEno/file [following]
# --2021-05-06 02:42:28--  https://ucc33452e3f43235022ddaba229d.dl.dropboxusercontent.com/cd/0/inline2/BN9DRN2xz2UEFkyRlsE3P8HirOIVNRsXrLZUe8J-sofoAHixFozfl2mVHqiSj_5-zqyBl1Us9fYEXwYejBlTosUaD7pLCGT_OC0q9o9wF-bwAKpv5Zw18JzjqVnkCD4U9DJ83ke1nFZBrpLHhRouRLec52Ul0yTtZGHO1Bmj_2gDz8fwcgRK3qPm_rT6g_h9960QKsTpCDfugI4R1j3RdBOIwTs0kif1obTtjWH2pCoIp33ZV45c70oL_GX5EOXnReokrAp1VOajrHzyzqh4wOowgN0wUQ8AIZVYQMp64dzZnWwt4GLbXYOTjRf6ju3-LhZjajSrm4Yp7_v0KTC_9pXG_Dw7nySEJBWBKeKyDB5y9PvEZ8-7ZitrPqtzuaDGEno/file
# Reusing existing connection to ucc33452e3f43235022ddaba229d.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 71969233 (69M) [application/zip]
# Saving to: ‘3vids_no_tensors.zip’
#
# 3vids_no_tensors.zi 100%[===================>]  68.63M   171MB/s    in 0.4s
#
# 2021-05-06 02:42:29 (171 MB/s) - ‘3vids_no_tensors.zip’ saved [71969233/71969233]
#
# Archive:  /content/3vids_no_tensors.zip
#    creating: 3vids_no_tensors/
#    creating: 3vids_no_tensors/opticFlow/
#   inflating: 3vids_no_tensors/.DS_Store
#   inflating: __MACOSX/3vids_no_tensors/._.DS_Store
#   inflating: 3vids_no_tensors/tensor4rnn.ipynb
#    creating: 3vids_no_tensors/frames/
#   inflating: 3vids_no_tensors/getOpticFlow.ipynb
#    creating: 3vids_no_tensors/opticFlow/tripping339/
#    creating: 3vids_no_tensors/opticFlow/tripping432/
#    creating: 3vids_no_tensors/opticFlow/tripping240/
#    creating: 3vids_no_tensors/frames/tripping339/
#    creating: 3vids_no_tensors/frames/tripping432/
#    creating: 3vids_no_tensors/frames/tripping240/
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0022.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0023.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0021.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0009.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0008.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0020.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0018.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0030.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0024.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0025.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0019.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0027.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0026.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0003.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0017.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0016.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0002.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0014.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0028.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0029.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0015.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0011.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0005.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0004.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0010.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0006.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0012.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0013.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping339/of0007.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0082.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0041.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0055.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0069.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0068.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0054.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0040.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0083.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0081.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0056.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0042.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0043.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0057.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0080.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0090.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0084.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0053.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0047.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0046.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0052.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0085.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0087.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0078.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0044.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0050.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0051.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0045.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0079.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0086.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0022.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0036.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0037.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0023.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0035.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0021.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0009.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0008.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0020.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0034.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0018.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0030.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0024.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0025.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0031.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0019.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0027.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0033.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0032.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0026.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0003.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0017.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0016.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0002.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0014.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0028.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0029.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0015.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0039.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0011.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0005.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0004.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0010.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0038.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0006.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0012.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0013.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0007.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0060.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0074.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0048.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0049.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0075.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0061.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0088.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0077.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0063.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0062.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0076.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0089.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0072.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0066.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0067.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0073.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0059.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0065.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0071.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0070.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0064.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping432/of0058.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0041.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0055.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0069.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0068.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0054.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0040.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0056.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0042.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0043.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0057.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0053.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0047.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0046.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0052.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0044.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0050.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0051.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0045.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0022.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0036.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0037.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0023.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0035.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0021.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0009.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0008.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0020.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0034.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0018.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0030.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0024.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0025.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0031.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0019.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0027.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0033.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0032.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0026.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0003.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0017.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0016.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0002.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0014.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0028.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0029.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0015.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0039.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0011.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0005.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0004.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0010.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0038.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0006.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0012.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0013.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0007.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0060.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0048.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0049.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0061.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0063.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0062.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0072.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0066.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0067.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0073.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0059.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0065.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0071.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0070.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0064.flo
#   inflating: 3vids_no_tensors/opticFlow/tripping240/of0058.flo
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0026.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0027.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0019.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0025.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0024.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0030.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0018.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0020.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0008.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0009.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0021.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0023.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0022.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0007.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0013.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0012.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0006.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0010.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0004.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0005.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0011.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0015.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0001.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0029.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0028.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0014.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0002.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0016.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0017.png
#   inflating: 3vids_no_tensors/frames/tripping339/rdx0003.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0026.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0032.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0033.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0027.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0019.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0031.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0025.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0024.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0030.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0018.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0034.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0020.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0008.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0009.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0021.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0035.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0023.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0037.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0036.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0022.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0086.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0079.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0045.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0051.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0050.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0044.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0078.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0087.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0085.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0052.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0046.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0047.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0053.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0084.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0090.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0080.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0057.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0043.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0042.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0056.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0081.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0083.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0040.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0054.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0068.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0069.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0055.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0041.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0082.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0058.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0064.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0070.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0071.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0065.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0059.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0073.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0067.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0066.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0072.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0089.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0076.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0062.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0063.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0077.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0088.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0061.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0075.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0049.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0048.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0074.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0060.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0007.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0013.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0012.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0006.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0038.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0010.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0004.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0005.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0011.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0039.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0015.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0001.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0029.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0028.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0014.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0002.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0016.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0017.png
#   inflating: 3vids_no_tensors/frames/tripping432/rdx0003.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0026.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0032.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0033.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0027.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0019.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0031.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0025.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0024.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0030.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0018.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0034.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0020.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0008.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0009.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0021.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0035.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0023.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0037.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0036.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0022.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0045.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0051.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0050.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0044.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0052.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0046.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0047.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0053.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0057.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0043.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0042.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0056.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0040.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0054.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0068.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0069.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0055.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0041.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0058.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0064.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0070.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0071.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0065.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0059.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0073.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0067.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0066.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0072.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0062.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0063.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0061.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0049.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0048.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0060.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0007.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0013.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0012.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0006.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0038.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0010.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0004.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0005.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0011.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0039.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0015.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0001.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0029.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0028.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0014.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0002.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0016.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0017.png
#   inflating: 3vids_no_tensors/frames/tripping240/rdx0003.png

# %%
# Return a circular mask of (True/False) 2d array
def create_circular_mask(shape, x, y, r):
    h, w = shape

    Y, X = np.ogrid[:h, :w]
    dist_from_center_mat = np.sqrt((X - x)**2 + (Y - y)**2)

    mask = dist_from_center_mat <= r
    return mask

def get_masked_img(img, x, y, r):
  mask = create_circular_mask(img.shape, x, y, r)
  masked = img.copy()
  masked[~mask] = 0
  return masked

# %%
import numpy as np
from scipy import ndimage
from skimage import color

# from RAFT/core/utils
from utils.frame_utils import readFlow as read_flow
from utils import flow_viz

def get_xy_coord_for_flo(flo_im, show_plot=False):
    # flo_im = flow_viz.flow_to_image(read_flow(flo_file))
    if show_plot:
        ic("visualized flow file")
        plt.imshow(flo_im)
        plt.show()

    gray_flo = color.rgb2gray(flo_im)
    if show_plot:
        ic("grayscale flow")
        plt.imshow(gray_flo, cmap='gray')
        plt.show()

    # Invert the intensity so that "active" spots have higher numerical value in range [0, 1]
    gray_flo = (gray_flo - 1 ) * -1
    if show_plot:
        ic("grayscale flow (inverted high=1)")
        plt.imshow(gray_flo, cmap='gray')
        plt.show()
        ic(ndimage.measurements.center_of_mass(gray_flo))

    # Exponeniate the pixel values; they will still remain in [0, 1]
    gray_flo = gray_flo ** 4
    if show_plot:
        ic("exponentiated (** 4) grayscale flow")
        plt.imshow(gray_flo, cmap='gray')
        plt.show()
        ic(ndimage.measurements.center_of_mass(gray_flo))

    (h, w) = ndimage.measurements.center_of_mass(gray_flo)
    return (w, h)  # return in (x, y) format

# %% [markdown]
# ======================================================================================================================
#
# ======================================================================================================================

# %% [markdown]
# # Detectron2 Beginner's Tutorial
#
# <img src="https://dl.fbaipublicfiles.com/detectron2/Detectron2-Logo-Horz.png" width="500">
#
# Welcome to detectron2! This is the official colab tutorial of detectron2. Here, we will go through some basics usage of detectron2, including the following:
# * Run inference on images or videos, with an existing detectron2 model
# * Train a detectron2 model on a new dataset
#
# You can make a copy of this tutorial by "File -> Open in playground mode" and make changes there. __DO NOT__ request access to this tutorial.

# %% [markdown]
# # Install detectron2

# %%
# install dependencies: 
# !pip install pyyaml==5.1
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
# !gcc --version
# opencv is pre-installed on colab
# Out:
# Collecting pyyaml==5.1
#   Downloading https://files.pythonhosted.org/packages/9f/2c/9417b5c774792634834e730932745bc09a7d36754ca00acf1ccd1ac2594d/PyYAML-5.1.tar.gz (274kB)
#      |████████████████████████████████| 276kB 19.8MB/s
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.1-cp37-cp37m-linux_x86_64.whl size=44074 sha256=cae49009f46c68b2bae56f79fdf8aa43c7928dbebdd0abfd77b710c5d8246017
#   Stored in directory: /root/.cache/pip/wheels/ad/56/bc/1522f864feb2a358ea6f1a92b4798d69ac783a28e80567a18b
# Successfully built pyyaml
# Installing collected packages: pyyaml
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed pyyaml-5.1
# 1.8.1+cu101 True
# gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# install detectron2: (Colab has CUDA 10.1 + torch 1.8)
# See https://detectron2.readthedocs.io/tutorials/install.html for instructions
import torch
assert torch.__version__.startswith("1.8")   # need to manually install torch 1.8 if Colab changes its default version
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.8/index.html
# exit(0)  # After installation, you need to "restart runtime" in Colab. This line can also restart runtime
# Out:
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.8/index.html
# Collecting detectron2
#   Downloading https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.8/detectron2-0.4%2Bcu101-cp37-cp37m-linux_x86_64.whl (6.2MB)
#      |████████████████████████████████| 6.2MB 596kB/s
# Collecting omegaconf>=2
#   Downloading https://files.pythonhosted.org/packages/d0/eb/9d63ce09dd8aa85767c65668d5414958ea29648a0eec80a4a7d311ec2684/omegaconf-2.0.6-py3-none-any.whl
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.7/dist-packages (from detectron2) (1.1.0)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.7/dist-packages (from detectron2) (4.41.1)
# Collecting yacs>=0.1.6
#   Downloading https://files.pythonhosted.org/packages/38/4f/fe9a4d472aa867878ce3bb7efb16654c5d63672b86dc0e6e953a67018433/yacs-0.1.8-py3-none-any.whl
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from detectron2) (0.16.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.7/dist-packages (from detectron2) (1.3.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from detectron2) (1.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from detectron2) (3.2.2)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from detectron2) (2.0.2)
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.7/dist-packages (from detectron2) (7.1.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from detectron2) (2.4.1)
# Collecting iopath>=0.1.2
#   Downloading https://files.pythonhosted.org/packages/21/d0/22104caed16fa41382702fed959f4a9b088b2f905e7a82e4483180a2ec2a/iopath-0.1.8-py3-none-any.whl
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from detectron2) (0.8.9)
# Collecting fvcore<0.1.4,>=0.1.3
#   Downloading https://files.pythonhosted.org/packages/6b/68/2bacb80e13c4084dfc37fec8f17706a1de4c248157561ff33e463399c4f5/fvcore-0.1.3.post20210317.tar.gz (47kB)
#      |████████████████████████████████| 51kB 8.1MB/s
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.7/dist-packages (from omegaconf>=2->detectron2) (5.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from omegaconf>=2->detectron2) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pydot->detectron2) (2.4.7)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.7/dist-packages (from matplotlib->detectron2) (1.19.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->detectron2) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->detectron2) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->detectron2) (0.10.0)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.7/dist-packages (from pycocotools>=2.0.2->detectron2) (0.29.22)
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools>=2.0.2->detectron2) (56.0.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (1.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (0.4.4)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (1.32.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (1.0.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (0.36.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (2.23.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (0.12.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (3.12.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (1.8.0)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/68/33/cb524f4de298509927b90aa5ee34767b9a2b93e663cf354b2a3efa2b4acd/portalocker-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (4.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->detectron2) (3.10.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2020.12.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard->detectron2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard->detectron2) (3.4.1)
# Building wheels for collected packages: fvcore
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.3.post20210317-cp37-none-any.whl size=58543 sha256=eff1c99d8b80bfa2ee4f397692fb3a8947d14289ca3dbd020ccbc44acd4ac161
#   Stored in directory: /root/.cache/pip/wheels/d2/ee/3a/5c531df777c03d8c67f22c65f97d6f75321087482d05a9b218
# Successfully built fvcore
# Installing collected packages: omegaconf, yacs, portalocker, iopath, fvcore, detectron2
# Successfully installed detectron2-0.4+cu101 fvcore-0.1.3.post20210317 iopath-0.1.8 omegaconf-2.0.6 portalocker-2.3.0 yacs-0.1.8

# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %% [markdown]
# # Run a pre-trained detectron2 model

# %%
# !wget http://images.cocodataset.org/val2017/000000439715.jpg -q -O input.jpg
# im = cv2.imread("./input.jpg")

# im = flo_0.copy()
# cv2_imshow(im)

# %% [markdown]
# Then, we create a detectron2 config and a detectron2 `DefaultPredictor` to run inference on this image.

# %%
cfg = get_cfg()
# add project-specific config (e.g., TensorMask) here if you're not running a model in detectron2's core library
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
# Find a model from detectron2's model zoo. You can use the https://dl.fbaipublicfiles... url as well
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
predictor = DefaultPredictor(cfg)
# outputs = predictor(im)

# %%
# # look at the outputs. See https://detectron2.readthedocs.io/tutorials/models.html#model-output-format for specification
# ic(outputs["instances"].pred_classes.shape)
# ic(outputs["instances"].pred_classes)
# # https://detectron2.readthedocs.io/en/latest/modules/structures.html#detectron2.structures.Boxes
# ic(outputs["instances"].pred_boxes.tensor.shape)
# ic(outputs["instances"].pred_boxes)
# ic(outputs["instances"].pred_masks.shape)
# ic(outputs["instances"].pred_masks)
# print('')

# %%
# # We can use `Visualizer` to draw the predictions on the image.
# v = Visualizer(im[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
# out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
# cv2_imshow(out.get_image()[:, :, ::-1])

# %% [markdown]
# # Using Detectron Bounding Box to Generate "radius" for given (x, y) coords

# %% [markdown]
# #Putting it all together

# %%
# One possible way to discern a radius is to take the average smallest
# dimension of each bounding box.
def avg_shortest_bbox_dimension(bbox_list):
    sum_of_shortest_dimensions = 0
    for x1, y1, x2, y2 in bbox_list:
        sum_of_shortest_dimensions += min(x2 - x1, y2 - y1)

    return sum_of_shortest_dimensions / len(bbox_list)


def generate_fove8n_labels(input_output_dirs, detector2_predictor):
    '''
    input_output_dirs: list of tuple of (input frame directory,
                                         input optical flow frame directory,
                                         output label file directory)
    detector2_predictor: a pre-trained, initialized detector2 predictor object
    '''
    for (frame_dir, flo_frame_dir, output_dir) in input_output_dirs:
        # Gather and sort all of the frame and optical flow files.
        frame_files = glob.glob(os.path.join(frame_dir, '*.png'))
        frame_files = sorted(frame_files)
        flo_files = glob.glob(os.path.join(flo_frame_dir, '*.flo'))
        flo_files = sorted(flo_files)
        assert len(frame_files) == len(flo_files) + 1, \
            "should be n and n - 1 frames: {} {}".format(frame_dir, flo_frame_dir)

        # Generate the candidate focal points for each optical flow frame.
        coords = []
        for flo_file in flo_files:
            flo_im = flow_viz.flow_to_image(read_flow(flo_file))
            (x, y) = get_xy_coord_for_flo(flo_im)  # returns (height, width)
            coords.append((x, y))

        # Pad the optic flow-derived coordinates with an extra duplicate,
        # representing the missing first frame.
        coords.insert(0, coords[0])

        # Run Detector2 to gather potential bounding boxes of items.
        bbox_lists = []
        for frame_file in frame_files:
            im = cv2.imread(frame_file)
            outputs = predictor(im)
            # https://detectron2.readthedocs.io/en/latest/modules/structures.html
            bbox_tensors =  outputs["instances"].pred_boxes.tensor
            bboxes = []
            for bbox_tensor in bbox_tensors:
                bboxes.append(bbox_tensor.tolist())
            bbox_lists.append(bboxes)

        assert len(coords) == len(bbox_lists)

        # Structure the bbox lists into bbox tuples for easier referencing.
        bbox_lists = [[(b[0], b[1], b[2], b[3]) for b in bbox_list] for bbox_list in bbox_lists]

        # Filter the bounding boxes for those that contain the focal point.
        filtered_bbox_lists = []
        for ((x, y), bboxes) in zip(coords, bbox_lists):
            containing_bboxes = []
            for (x1, y1, x2, y2) in bboxes:
                if x1 < x < x2 and y1 < y < y2:
                    containing_bboxes.append((x1, y1, x2, y2))
            filtered_bbox_lists.append(containing_bboxes)

        assert len(filtered_bbox_lists) == len(bbox_lists)

        # Generate guesses for reasonable radii.
        xyrs = []
        last_r = None
        for ((x, y), bboxes) in zip(coords, filtered_bbox_lists):
            # If there's no bounding box, just use the last radius.
            if len(bboxes) == 0:
                # If we haven't used a real radius yet, throw an error
                if not last_r:
                    raise Exception('No bounding boxes overlapped the focal point int the first frame: {}'.format(frame_dir))
                xyrs.append((x, y, last_r))
            else:
                current_r = avg_shortest_bbox_dimension(bboxes)
                xyrs.append((x, y, current_r))
                last_r = current_r

        # Write the labels as text files to the given directory.
        with open(os.path.join(output_dir, 'labels.txt'), 'w') as labels_file:
            for (x, y, r) in xyrs:
                label_line = "{} {} {}\n".format(x, y, r)
                labels_file.write(label_line)

# %%
tripping240_in_out = ('/content/3vids_no_tensors/frames/tripping240/',
                      '/content/3vids_no_tensors/opticFlow/tripping240/',
                      '/content/3vids_no_tensors/labels/tripping240/')

tripping339_in_out = ('/content/3vids_no_tensors/frames/tripping339/',
                      '/content/3vids_no_tensors/opticFlow/tripping339/',
                      '/content/3vids_no_tensors/labels/tripping339/')

tripping432_in_out = ('/content/3vids_no_tensors/frames/tripping432/',
                      '/content/3vids_no_tensors/opticFlow/tripping432/',
                      '/content/3vids_no_tensors/labels/tripping432/')
# problem with tripping240 -- no bounding box for first frame that overlaps focus area.
in_out_dirs = [tripping339_in_out, tripping432_in_out]

generate_fove8n_labels(in_out_dirs, predictor)
